# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### Import Required Libraries
# - `from bs4 import BeautifulSoup`: Imports BeautifulSoup for parsing HTML content.
# - `import requests`: Imports the requests library to make HTTP requests.
# - `import pandas as pd`: Imports pandas for data manipulation and storage.

# %%
URL = "https://www.amazon.in/s?k=playstation+5&crid=302ZJMTZG1JP1&sprefix=playstation+%2Caps%2C369&ref=nb_sb_noss_2"

# %% [markdown]
# ### Set Amazon Search URL
# - `URL = ...`: Defines the Amazon search results page URL for PlayStation 5.

# %%
HEADERS = ({'user-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36 Edg/143.0.0.0', 'Accept-Language': 'en-US, en;q=0.5'})

# %% [markdown]
# ### Set Request Headers
# - `HEADERS = {...}`: Sets custom headers for the HTTP request to mimic a browser and avoid being blocked by Amazon.

# %%
webpage = requests.get(URL,headers=HEADERS)

# %% [markdown]
# ### Send HTTP Request
# - `webpage = requests.get(URL, headers=HEADERS)`: Sends a GET request to the Amazon search URL with the specified headers and stores the response.

# %%
webpage
# Out:
# <Response [200]>

# %% [markdown]
# ### Display Response Object
# - `webpage`: Displays the response object to check the status of the HTTP request.

# %%
webpage.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function
# ...

# %% [markdown]
# ### View Raw HTML Content
# - `webpage.content`: Displays the raw HTML content of the fetched web page.

# %%
type(webpage.content)
# Out:
# bytes

# %% [markdown]
# ### Check Content Type
# - `type(webpage.content)`: Checks the data type of the web page content (should be bytes).

# %%
soup = BeautifulSoup(webpage.content, 'html.parser')

# %% [markdown]
# ### Parse HTML with BeautifulSoup
# - `soup = BeautifulSoup(webpage.content, 'html.parser')`: Parses the HTML content using BeautifulSoup for further data extraction.

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %% [markdown]
# ### Display Parsed HTML Object
# - `soup`: Displays the BeautifulSoup object to inspect the parsed HTML structure.

# %%
links = soup.find_all(
    'a',
    attrs={'class': 'a-link-normal s-line-clamp-2 s-line-clamp-3-for-col-12 s-link-style a-text-normal'}
)

# %% [markdown]
# ### Find Product Links
# - `links = soup.find_all(...)`: Finds all anchor tags with specific classes that likely contain product links from the search results.

# %%
links
# Out:
# [<a class="a-link-normal s-line-clamp-2 s-line-clamp-3-for-col-12 s-link-style a-text-normal" href="/sspa/click?ie=UTF8&amp;spc=MToyMTYxMzIzMTI0MzA1MTk1OjE3NjY3NDA0NDg6c3BfYXRmOjMwMDgxMDM1MzA1MTEzMjo6MDo6&amp;url=%2FSage-Controllers-Controller-compatible-Professional%2Fdp%2FB09XJDF19K%2Fref%3Dsr_1_1_sspa%3Fcrid%3D302ZJMTZG1JP1%26dib%3DeyJ2IjoiMSJ9.LFVt-P4VfYSI0tw5J_cegSK92whhtXrjDDzVMLUNuoUrbra1aW9IHQikmaSBOtq3-ttgSeldDeaInlrEqS4-sHLPSx4n2OWQLX0GFbZU_mrYCzQj0df5O9uw39XMo8EgspjVydUgsLSjLaMc82zUOONHHYTRe0Ze3rVFf1n_32lxO4awIK5srQwMQaxdmRp6sgKS8UtUtoS3mk21MV2LRsK-TPWLdnL0DnelhlBO5_4.mQFEX0P5TLxyiR35p3aWaMKmd5BMJCEmNuC5tTvf8fg%26dib_tag%3Dse%26keywords%3Dplaystation%2B5%26qid%3D1766740448%26sprefix%3Dplaystation%2B%252Caps%252C369%26sr%3D8-1-spons%26aref%3DTZNp6TCQ71%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1&amp;aref=TZNp6TCQ71&amp;sp_cr=ZAZ" target="_blank"><h2 aria-label="Sponsored Ad - Sage Controllers PRO+ Controller compatible with PS5 Console &amp; PC | Custommade Wireless PS5 Ga
# ...

# %% [markdown]
# ### Display Product Links
# - `links`: Displays the list of found product link elements.

# %%
link = links[1].get('href')

# %% [markdown]
# ### Extract a Product Link
# - `link = links[1].get('href')`: Extracts the href attribute from the second product link in the list.

# %%
product_list = 'https://amazon.com'+link

# %% [markdown]
# ### Build Full Product URL
# - `product_list = 'https://amazon.com'+link`: Constructs the full URL for the selected product by combining the base URL with the extracted link.

# %%
product_list
# Out:
# 'https://amazon.com/sspa/click?ie=UTF8&spc=MToyMTYxMzIzMTI0MzA1MTk1OjE3NjY3NDA0NDg6c3BfYXRmOjMwMDYyMzEzNjI0ODkzMjo6MDo6&url=%2FPowerA-USB-C%25C2%25AE-PlayStation%25C2%25AE5-Officially-Licensed%2Fdp%2FB0DB66W45R%2Fref%3Dsr_1_2_sspa%3Fcrid%3D302ZJMTZG1JP1%26dib%3DeyJ2IjoiMSJ9.LFVt-P4VfYSI0tw5J_cegSK92whhtXrjDDzVMLUNuoUrbra1aW9IHQikmaSBOtq3-ttgSeldDeaInlrEqS4-sHLPSx4n2OWQLX0GFbZU_mrYCzQj0df5O9uw39XMo8EgspjVydUgsLSjLaMc82zUOONHHYTRe0Ze3rVFf1n_32lxO4awIK5srQwMQaxdmRp6sgKS8UtUtoS3mk21MV2LRsK-TPWLdnL0DnelhlBO5_4.mQFEX0P5TLxyiR35p3aWaMKmd5BMJCEmNuC5tTvf8fg%26dib_tag%3Dse%26keywords%3Dplaystation%2B5%26qid%3D1766740448%26sprefix%3Dplaystation%2B%252Caps%252C369%26sr%3D8-2-spons%26aref%3DlQcAukfd7P%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1&aref=lQcAukfd7P&sp_cr=ZAZ'

# %% [markdown]
# ### Display Product URL
# - `product_list`: Displays the constructed product URL.

# %%
new_webpage = requests.get(product_list, headers=HEADERS)

# %% [markdown]
# ### Fetch Product Page
# - `new_webpage = requests.get(product_list, headers=HEADERS)`: Sends a GET request to the product page URL to fetch its HTML content.

# %%
new_webpage
# Out:
# <Response [200]>

# %% [markdown]
# ### Display Product Page Response
# - `new_webpage`: Displays the response object for the product page request.

# %%
new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

# %% [markdown]
# ### Parse Product Page HTML
# - `new_soup = BeautifulSoup(new_webpage.content, 'html.parser')`: Parses the product page HTML content for data extraction.

# %%
new_soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %% [markdown]
# ### Display Parsed Product Page
# - `new_soup`: Displays the BeautifulSoup object for the product page to inspect its structure.

# %%
product = new_soup.find('span', attrs={'id':'productTitle'})

# %% [markdown]
# ### Find Product Title Element
# - `product = new_soup.find('span', attrs={'id':'productTitle'})`: Searches for the product title element by its ID in the parsed product page.

# %%
product

# %% [markdown]
# ### Display Product Title Element
# - `product`: Displays the found product title element (or None if not found).

# %%
if product is not None:
	product_title = product.text.strip()
	print(product_title)
else:
	print("Product title not found.")
# Out:
# Product title not found.

# %% [markdown]
# ### Extract and Print Product Title
# - Checks if the product element was found.
# - If found, extracts and prints the product title text.
# - If not found, prints a message indicating the title was not found.

# %%
# Using Selenium and webdriver-manager to fetch product title with Chrome browser
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

# Set up Chrome options
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode (no browser UI)
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# Start the Chrome driver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Open the product page
driver.get(product_list)

# Wait for the page to load
time.sleep(3)  # You can use WebDriverWait for better reliability

try:
    product_title_elem = driver.find_element(By.ID, 'productTitle')
    product_title = product_title_elem.text.strip()
    print(product_title)
except Exception as e:
    print('Product title not found using Selenium (Chrome):', e)

# Clean up
driver.quit()
# Out:
# PowerA USB-C® to USB-C 10 ft. Cable for PlayStation®5, Charge and Play, Recharge, DualSense Edge Compatible, PSVR2 Compatible, PS Portal Compatible, Officially Licensed

# %% [markdown]
# ### Extract Product Title Using Selenium
# - Imports Selenium and related modules for browser automation.
# - Sets up Chrome browser in headless mode.
# - Opens the product page and waits for it to load.
# - Tries to find and print the product title using Selenium.
# - Handles exceptions if the title is not found.
# - Closes the browser after extraction.

# %%
# Parse the Amazon search results page and extract product data
from bs4 import BeautifulSoup
import pandas as pd

# Use the original search page content (already fetched)
soup = BeautifulSoup(webpage.content, 'html.parser')

# Find all product containers (adjust class as needed for Amazon's structure)
products = soup.find_all('div', {'data-component-type': 's-search-result'})

data = []
for product in products:
    title_elem = product.find('span', {'class': 'a-size-medium a-color-base a-text-normal'})
    price_whole = product.find('span', {'class': 'a-price-whole'})
    price_fraction = product.find('span', {'class': 'a-price-fraction'})
    rating_elem = product.find('span', {'class': 'a-icon-alt'})
    link_elem = product.find('a', {'class': 'a-link-normal s-no-outline'})

    title = title_elem.text.strip() if title_elem else None
    price = None
    if price_whole and price_fraction:
        price = price_whole.text.strip() + price_fraction.text.strip()
    elif price_whole:
        price = price_whole.text.strip()
    rating = rating_elem.text.strip() if rating_elem else None
    link = 'https://www.amazon.in' + link_elem['href'] if link_elem else None

    data.append({'Title': title, 'Price': price, 'Rating': rating, 'Link': link})

# %% [markdown]
# ### Parse and Extract Product Data from Search Results
# - Imports BeautifulSoup and pandas again (for clarity in this cell).
# - Parses the original search results page.
# - Finds all product containers on the page.
# - For each product, extracts:
#   - Title
#   - Price (whole and fraction)
#   - Rating
#   - Product link
# - Appends the extracted data as a dictionary to a list.

# %%
# Create DataFrame from extracted data and save to CSV
df = pd.DataFrame(data)
df.to_csv('amazon_products.csv', index=False)
print('Saved to amazon_products.csv')
df.head()
# Out:
# Saved to amazon_products.csv
# Saved to amazon_products.csv
#   Title   Price              Rating  \
# 0  None  11,700  5.0 out of 5 stars
# 1  None     999  4.6 out of 5 stars
# 2  None  54,990  4.5 out of 5 stars
# 3  None  49,990  4.6 out of 5 stars
# 4  None   4,890  4.2 out of 5 stars
#
#                                                 Link
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2  https://www.amazon.in/Sony-CFI-2008A01X-PlaySt...
# 3  https://www.amazon.in/Sony-PlayStation%C2%AE5-...
# 4  https://www.amazon.in/DualSense-Wireless-Contr...

# %% [markdown]
# ### Save Extracted Data to CSV and Display
# - Creates a pandas DataFrame from the extracted product data.
# - Saves the DataFrame to a CSV file named 'amazon_products.csv'.
# - Prints a confirmation message.
# - Displays the first few rows of the DataFrame.
